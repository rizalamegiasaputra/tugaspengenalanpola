# %%
import pandas as pd
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv") #lokasi menyesuaikan
# printing the top 10 rows
display(data.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# a.2 Scatter plot : Fungsi yang digunakan untuk menampilkan scatter plot adalah fungs scatter().

# %%
#Matplotlib Lbrary
import pandas as pd
import matplotlib.pyplot as plt
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
# Scatter plot with day against tip
plt.scatter(data['smoker'], data['tip'])
# Adding Title to the Plot
plt.title("Scatter Plot")
# Setting the X and Y labels
plt.xlabel('smoker')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# Grafik akan lebih menarik dan informatif jika ditampilkan menggunakan colobar dengan parameter c dan s yang dapat dilihat pada sintaks berikut

# %%
import pandas as pd
import matplotlib.pyplot as plt
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
# Scatter plot with day against tip
#plt.scatter(data['sex'], data['tip'])
# Scatter plot with day against tip
plt.scatter(data['day'], data['tip'], c=data['size'], s=data['total_bill'])
# Adding Title to the Plot
plt.title("Scatter Plot")
# Setting the X and Y labels
plt.xlabel('Day')
plt.ylabel('Tip')
plt.colorbar()
plt.show()

# %% [markdown]
# a.3 line Chart : Untuk membuat line chart, dapat dilakukan dengan menggunakan fungsi plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
# Scatter plot with day against tip
plt.plot(data['tip'])
plt.plot(data['size'])
# Adding Title to the Plot
plt.title("Scatter Plot")
# Setting the X and Y labels
plt.xlabel('Day')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
#  a.4 Bar Chart : Untuk membuat bar chart, dapat dilakukan dengan menggunakan fungsi bar(). Fungsi ini akan menyajikan data kategori dalam suatu diagram batang dengan tinggi dan lebar tertentu. Modifikasi yang dilakukan di bagian ini.

# %%
# Bar chart
plt.bar(data['day'], data['tip'])
# Adding Title to the Plot
plt.title("Bar Chart")
# Out:
# Text(0.5, 1.0, 'Bar Chart')

# %% [markdown]
#  a.5 Histogram : Histogram pada dasarnya digunakan untuk merepresentasikan data dalam bentuk beberapa kelompok. Ini adalah jenis plot batang di mana sumbu X mewakili rentang bin sementara sumbu Y memberikan informasi tentang frekuensi. Fungsi hist() digunakan untuk menghitung dan membuat histogram. Berikut adalah sintaks untuk membuat histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
# hostogram of total_bills
plt.hist(data['total_bill'])
plt.title("Histogram")
# Adding the legends
plt.show()

# %% [markdown]
# b.	Seaborn : Seaborn adalah library dengan tampilan antarmuka style yang leboh baik. Untuk dapat menggunakan library ini dapat melakukan pemanggilan paket seaborn dengan perintah import. Sintakn di bawah ini memperlihatkan penggunakan seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
# draw lineplot
sns.li
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
plt.show()

# %% [markdown]
# **Tugas**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
sns.barplot(x='day',y='tip', data=data,hue='sex')
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
sns.histplot(x='total_bill', data=data, kde=True, hue='sex')
plt.show()

# %% [markdown]
# c.	Plotly : Plotly menjadikan grafik lebih atratktif dan dapat dilakukan kustomisasi.  Untuk dapat melakuka visualisasi ini, dapat menggunakan library plotly pada modul express.

# %% [markdown]
# c.1 scatter plot

# %%
import plotly.express as px
import pandas as pd
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
# plotting the scatter chart
fig = px.scatter(data, x="day", y="tip", color='sex')
# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# c.2 Line Chart

# %%
import plotly.express as px
import pandas as pd
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
# plotting the scatter chart
fig = px.line(data, y='tip', color='sex')
# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# c.3 Bar Chart

# %%
import plotly.express as px
import pandas as pd
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
# plotting the scatter chart
fig = px.bar(data, x='day', y='tip', color='sex')
# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# c.4 Histogram

# %%
import plotly.express as px
import pandas as pd
# reading the database
data = pd.read_csv("/content/sample_data/tips.csv")
# plotting the scatter chart
fig = px.histogram(data, x='total_bill', color='sex')
# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
